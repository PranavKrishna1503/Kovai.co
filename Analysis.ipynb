# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('dataset.csv')

df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")

start_date = '2023-04-01'
end_date = '2024-04-30'
df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_filtered.sort_values(by="Date", inplace=True)

a = df_filtered.head(30)

plt.figure(figsize=(10, 6))
plt.plot(a['Date'], a['MyWay'], color='red')
plt.xlabel("Date")
plt.ylabel("MyWay")
plt.title("MyWay Distribution")
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-100-f497761eb54b>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by="Date", inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('dataset.csv')

df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")

start_date = '2023-04-01'
end_date = '2024-04-30'
df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_filtered.sort_values(by="Date", inplace=True)

a = df_filtered.tail(30)

plt.figure(figsize=(10, 6))
plt.plot(a['Date'], a['MyWay'], color='red')
plt.xlabel("Date")
plt.ylabel("MyWay")

plt.xticks(rotation=45, fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-93-02b646201c47>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by="Date", inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('dataset.csv')

df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")
start_date = '2023-04-01'
end_date = '2024-04-30'
df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_filtered.sort_values(by="Date", inplace=True)

a = df_filtered.head(30)

plt.figure(figsize=(10, 6))
plt.bar(a['Date'], a['MyWay'], color='red')
plt.xlabel("Date")
plt.ylabel("MyWay")
plt.title("MyWay Distribution")
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-94-8cb51d8fb131>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by="Date", inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('dataset.csv')

df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")
start_date = '2023-04-01'
end_date = '2024-04-30'
df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_filtered.sort_values(by="Date", inplace=True)

a = df_filtered.tail(30)

plt.figure(figsize=(10, 6))
plt.bar(a['Date'], a['MyWay'], color='red')
plt.xlabel("Date")
plt.ylabel("MyWay")
plt.title("MyWay Distribution")
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-99-93826c5a3cbe>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by="Date", inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('dataset.csv')

df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")

start_date = '2023-05-01'
end_date = '2023-05-31'
df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_filtered.sort_values(by="Date", inplace=True)

a = df_filtered.tail(30)

plt.figure(figsize=(10, 6))
plt.plot(a['Date'], a['MyWay'], color='red')
plt.xlabel("Date")
plt.ylabel("MyWay")

plt.xticks(rotation=45, fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-103-d508a7b71a80>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.sort_values(by="Date", inplace=True)
